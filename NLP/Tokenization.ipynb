# %%
corpus = """Hello Welcome,to Ajay Soni NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Ajay Soni NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
##Tokenizatin
##sentence--> paragraphs
from nltk.tokenize import sent_tokenize

# %%
documnets = sent_tokenize(corpus)

# %%
documnets
# Out:
# ['Hello Welcome,to Ajay Soni NLP Tutorials.',
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
##tokenization
##paragraph --> words
##sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Ajay',
#  'Soni',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
print(wordpunct_tokenize(corpus))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Ajay', 'Soni', 'NLP', 'Tutorials', '.', 'Please', 'do', 'watch', 'the', 'entire', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Ajay',
#  'Soni',
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
